# %%
import sys

sys.path.append("..")

import importlib

import scripts.utils1 as utils1

importlib.reload(utils1)

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
delhi_results = utils1.train_holdout_model(
    city_name="Delhi",
    sequence_length=30,
    epochs=20
)
# Out:
# Training:
# 1980-01-01 to 2012-10-24
#
# Testing:
# 2012-10-25 to 2020-12-31
#
# Holdout:
# 2021-01-31 to 2025-12-31
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step

# %%
utils1.plot_predictions(
    delhi_results
)

# %%
utils1.plot_holdout_forecast(
    delhi_results
)

# %%
utils1.plot_holdout_predictions(
    delhi_results
)

# %%
mumbai_results = utils1.train_holdout_model(
    city_name="Mumbai",
    sequence_length=30,
    epochs=20
)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
utils1.plot_predictions(
    mumbai_results
)

# %%
utils1.plot_holdout_predictions(
    mumbai_results
)

# %%
bengaluru_results = utils1.train_holdout_model(
    city_name="Bengaluru",
    sequence_length=30,
    epochs=20
)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
utils1.plot_predictions(
    bengaluru_results
)

# %%
utils1.plot_holdout_predictions(
    bengaluru_results
)

# %%
hyderabad_results = utils1.train_holdout_model(
    city_name="Hyderabad",
    sequence_length=30,
    epochs=20
)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
utils1.plot_predictions(
    hyderabad_results
)

# %%
utils1.plot_holdout_predictions(
    hyderabad_results
)

# %%
ahmedabad_results = utils1.train_holdout_model(
    city_name="Ahmedabad",
    sequence_length=30,
    epochs=20
)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
utils1.plot_predictions(
    ahmedabad_results
)

# %%
utils1.plot_holdout_predictions(
    ahmedabad_results
)

# %%
chennai_results = utils1.train_holdout_model(
    city_name="Chennai",
    sequence_length=30,
    epochs=20
)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
utils1.plot_predictions(
    chennai_results
)

# %%
utils1.plot_holdout_predictions(
    chennai_results
)

# %%
kolkata_results = utils1.train_holdout_model(
    city_name="Kolkata",
    sequence_length=30,
    epochs=20
)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
utils1.plot_predictions(
    kolkata_results
)

# %%
utils1.plot_holdout_predictions(
    kolkata_results
)

# %%
surat_results = utils1.train_holdout_model(
    city_name="Surat",
    sequence_length=30,
    epochs=20
)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
utils1.plot_predictions(
    surat_results
)

# %%
utils1.plot_holdout_predictions(
    surat_results
)

# %%
pune_results = utils1.train_holdout_model(
    city_name="Pune",
    sequence_length=30,
    epochs=20
)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
utils1.plot_predictions(
    pune_results
)

# %%
utils1.plot_holdout_predictions(
    pune_results
)

# %%
jaipur_results = utils1.train_holdout_model(
    city_name="Jaipur",
    sequence_length=30,
    epochs=20
)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
utils1.plot_predictions(
    jaipur_results
)

# %%
utils1.plot_holdout_forecast(
    jaipur_results
)

# %%
utils1.plot_holdout_predictions(
    jaipur_results
)

# %%
results = [
    delhi_results,
    mumbai_results,
    bengaluru_results,
    hyderabad_results,
    ahmedabad_results,
    chennai_results,
    kolkata_results,
    surat_results,
    pune_results,
    jaipur_results
]

Comparison = utils1.create_Comparison_table(
    results
)

Comparison.index = Comparison.index + 1

Comparison
# Out:
#          City  Test RMSE  Holdout RMSE  Test MAE  Holdout MAE   Test R²  \
# 1       Delhi   1.035412      1.049364  0.780842     0.789600  0.977127
# 2      Mumbai   1.186483      1.236641  0.869751     0.893607  0.978021
# 3   Bengaluru   1.024652      1.046302  0.770425     0.795956  0.976608
# 4   Hyderabad   1.003726      1.034859  0.752570     0.780170  0.976218
# 5   Ahmedabad   1.227979      1.258945  0.904945     0.908417  0.977264
# 6     Chennai   1.002948      1.033278  0.753049     0.780226  0.976255
# 7     Kolkata   1.001242      1.033525  0.749861     0.779029  0.976335
# 8       Surat   1.199668      1.241798  0.876404     0.889575  0.977799
# 9        Pune   1.250614      1.310447  0.927432     0.939353  0.974746
# 10     Jaipur   1.106766      1.140465  0.815027     0.826171  0.977718
#
#     Holdout R²  Test Correlation  Holdout Correlation
# 1     0.974761          0.988576             0.988576
# 2     0.973959          0.988984             0.988984
# ...

# %%
Comparison.to_csv(
    "../outputs/Comparison_1980_2020_holdout.csv",
    index=True
)

print("CSV saved successfully!")
# Out:
# CSV saved successfully!
