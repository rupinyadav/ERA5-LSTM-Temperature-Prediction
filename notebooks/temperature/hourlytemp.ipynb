# %%
import numpy as np
import tensorflow as tf
import random

np.random.seed(42)

tf.random.set_seed(42)

random.seed(42)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782143818.437110    3891 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1782143818.443424    3891 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1782143819.686598    3891 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
import sys

sys.path.append("..")

import importlib

import scripts.temperature.hourlyutils as hourly

importlib.reload(hourly)
# Out:
# <module 'scripts.hourlyutils' from '/home/rupin/ERA5_LSTM_Project/notebooks/../scripts/hourlyutils.py'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from sklearn.metrics import r2_score

# %%
Delhi_results = hourly.train_hourly_model(
    city_name="Delhi",
    sequence_length=48,
    epochs=20
)
# Out:
# Training Period:
# 2000-01-01 to 2008-10-19
#
# Testing Period:
# 2008-10-19 to 2010-12-31
# E0000 00:00:1781617832.116650    2868 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step

# %%
hourly.plot_hourly_predictions(
    Delhi_results
)

# %%
Delhi_results.keys()
# Out:
# dict_keys(['city', 'model', 'history', 'rmse', 'mae', 'correlation', 'r2', 'predictions', 'actual', 'dates', 'scaler'])

# %%
scaler = Delhi_results["scaler"]

model = Delhi_results["model"]

# %%
hourly.plot_week_by_date(
    Delhi_results,
    "2009-07-10"
)

# %%
Mumbai_results = hourly.train_hourly_model(
    city_name="Mumbai",
    sequence_length=48,
    epochs=20
)
# Out:
# Training Period:
# 2000-01-01 to 2008-10-19
#
# Testing Period:
# 2008-10-19 to 2010-12-31
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step

# %%
hourly.plot_hourly_predictions(
        Mumbai_results
)

# %%
hourly.plot_week_by_date(
    Mumbai_results,
    "2009-07-10"
)

# %%
Bengaluru_results = hourly.train_hourly_model(
    city_name="Bengaluru",
    sequence_length=48,
    epochs=20
)
# Out:
# Training Period:
# 2000-01-01 to 2008-10-19
#
# Testing Period:
# 2008-10-19 to 2010-12-31
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step

# %%
hourly.plot_hourly_predictions(
    Bengaluru_results
)

# %%
hourly.plot_week_by_date(
    Bengaluru_results,
    "2009-07-10"
)

# %%
Hyderabad_results = hourly.train_hourly_model(
    city_name="Hyderabad",
    sequence_length=48,
    epochs=20
)
# Out:
# Training Period:
# 2000-01-01 to 2008-10-19
#
# Testing Period:
# 2008-10-19 to 2010-12-31
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step

# %%
hourly.plot_hourly_predictions(
    Hyderabad_results
)

# %%
hourly.plot_week_by_date(
    Hyderabad_results,
    "2009-07-10"
)

# %%
Chennai_results = hourly.train_hourly_model(
    city_name="Chennai",
    sequence_length=48,
    epochs=20
)
# Out:
# Training Period:
# 2000-01-01 to 2008-10-19
#
# Testing Period:
# 2008-10-19 to 2010-12-31
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step

# %%
hourly.plot_hourly_predictions(
    Chennai_results
)

# %%
hourly.plot_week_by_date(
    Chennai_results,
    "2009-07-10"
)

# %%
Ahmedabad_results = hourly.train_hourly_model(
    city_name="Ahmedabad",
    sequence_length=48,
    epochs=20
)
# Out:
# Training Period:
# 2000-01-01 to 2008-10-19
#
# Testing Period:
# 2008-10-19 to 2010-12-31
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step

# %%
hourly.plot_hourly_predictions(
    Ahmedabad_results
)

# %%
hourly.plot_week_by_date(
    Ahmedabad_results,
    "2009-07-10"
)

# %%
Kolkata_results = hourly.train_hourly_model(
    city_name="Kolkata",
    sequence_length=48,
    epochs=20
)
# Out:
# Training Period:
# 2000-01-01 to 2008-10-19
#
# Testing Period:
# 2008-10-19 to 2010-12-31
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step

# %%
hourly.plot_hourly_predictions(
    Kolkata_results
)

# %%
hourly.plot_week_by_date(
    Kolkata_results,
    "2009-07-10"
)

# %%
Surat_results = hourly.train_hourly_model(
    city_name="Surat",
    sequence_length=48,
    epochs=20
)
# Out:
# Training Period:
# 2000-01-01 to 2008-10-19
#
# Testing Period:
# 2008-10-19 to 2010-12-31
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step

# %%
hourly.plot_hourly_predictions(
    Surat_results
)

# %%
hourly.plot_week_by_date(
    Surat_results,
    "2009-07-10"
)

# %%
Pune_results = hourly.train_hourly_model(
    city_name="Pune",
    sequence_length=48,
    epochs=20
)
# Out:
# Training Period:
# 2000-01-01 to 2008-10-19
#
# Testing Period:
# 2008-10-19 to 2010-12-31
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step

# %%
hourly.plot_hourly_predictions(
    Pune_results
)

# %%
hourly.plot_week_by_date(
    Pune_results,
    "2009-07-10"
)

# %%
Jaipur_results = hourly.train_hourly_model(
    city_name="Jaipur",
    sequence_length=48,
    epochs=20
)
# Out:
# Training Period:
# 2000-01-01 to 2008-10-19
#
# Testing Period:
# 2008-10-19 to 2010-12-31
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step

# %%
hourly.plot_hourly_predictions(
    Jaipur_results
)

# %%
hourly.plot_week_by_date(
    Jaipur_results,
    "2009-07-10"
)

# %%
test_results = [
    Delhi_results,
    Mumbai_results,
    Bengaluru_results,
    Hyderabad_results,
    Ahmedabad_results,
    Chennai_results,
    Kolkata_results,
    Surat_results,
    Pune_results,
    Jaipur_results
]

comparison = hourly.create_comparison_table(
   test_results
)

comparison.index = comparison.index + 1

comparison
# Out:
#          City      RMSE       MAE        R²   Correlation
# 1       Delhi  0.439988  0.287591  0.996970      0.998519
# 2      Mumbai  0.384637  0.246388  0.998130      0.999085
# 3   Bengaluru  0.428460  0.273734  0.997070      0.998535
# 4   Hyderabad  0.421990  0.268791  0.996967      0.998485
# 5   Ahmedabad  0.413701  0.267522  0.997932      0.998973
# 6     Chennai  0.427825  0.277538  0.996883      0.998459
# 7     Kolkata  0.417238  0.267968  0.997035      0.998528
# 8       Surat  0.398076  0.257761  0.998017      0.999067
# 9        Pune  0.443197  0.294064  0.997464      0.998776
# 10     Jaipur  0.463489  0.297743  0.996965      0.998519

# %%
comparison.to_csv(
    "../outputs/comparison_2000_2010_hourly.csv",
    index=True
)

print("CSV saved successfully!")
# Out:
# CSV saved successfully!

# %% [markdown]
# HOLDOUT DATA

# %% [markdown]
# 2026-05-01 → 2026-05-06
# and
# 2026-05-24 → 2026-06-06

# %%
delhi_holdout = hourly.evaluate_holdout_period(
    city_name="Delhi",
    model=Delhi_results["model"],
    scaler=Delhi_results["scaler"],
    holdout_file="../data/Delhi_May_June_2026.txt"
)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
hourly.plot_holdout_period(
    delhi_holdout
)

# %%
mumbai_holdout = hourly.evaluate_holdout_period(
    city_name="Mumbai",
    model=Mumbai_results["model"],
    scaler=Mumbai_results["scaler"],
    holdout_file="../data/Mumbai_May_June_2026.txt"
)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
hourly.plot_holdout_period(
    mumbai_holdout
)

# %%
bengaluru_holdout = hourly.evaluate_holdout_period(
    city_name="Bengaluru",
    model=Bengaluru_results["model"],
    scaler=Bengaluru_results["scaler"],
    holdout_file="../data/Bengaluru_May_June_2026.txt"
)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
hourly.plot_holdout_period(
    bengaluru_holdout
)

# %%
hyderabad_holdout = hourly.evaluate_holdout_period(
    city_name="Hyderabad",
    model=Hyderabad_results["model"],
    scaler=Hyderabad_results["scaler"],
    holdout_file="../data/Hyderabad_May_June_2026.txt"
)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %%
hourly.plot_holdout_period(
    hyderabad_holdout
)

# %%
ahmedabad_holdout = hourly.evaluate_holdout_period(
    city_name="Ahmedabad",
    model=Ahmedabad_results["model"],
    scaler=Ahmedabad_results["scaler"],
    holdout_file="../data/Ahmedabad_May_June_2026.txt"
)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
hourly.plot_holdout_period(
    ahmedabad_holdout
)

# %%
chennai_holdout = hourly.evaluate_holdout_period(
    city_name="Chennai",
    model=Chennai_results["model"],
    scaler=Chennai_results["scaler"],
    holdout_file="../data/Chennai_May_June_2026.txt"
)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
hourly.plot_holdout_period(
    chennai_holdout
)

# %%
kolkata_holdout = hourly.evaluate_holdout_period(
    city_name="Kolkata",
    model=Kolkata_results["model"],
    scaler=Kolkata_results["scaler"],
    holdout_file="../data/Kolkata_May_June_2026.txt"
)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %%
hourly.plot_holdout_period(
    kolkata_holdout
)

# %%
surat_holdout = hourly.evaluate_holdout_period(
    city_name="Surat",
    model=Surat_results["model"],
    scaler=Surat_results["scaler"],
    holdout_file="../data/Surat_May_June_2026.txt"
)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
hourly.plot_holdout_period(
    surat_holdout
)

# %%
pune_holdout = hourly.evaluate_holdout_period(
    city_name="Pune",
    model=Pune_results["model"],
    scaler=Pune_results["scaler"],
    holdout_file="../data/Pune_May_June_2026.txt"
)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
hourly.plot_holdout_period(
    pune_holdout
)

# %%
jaipur_holdout = hourly.evaluate_holdout_period(
    city_name="Jaipur",
    model=Jaipur_results["model"],
    scaler=Jaipur_results["scaler"],
    holdout_file="../data/Jaipur_May_June_2026.txt"
)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
hourly.plot_holdout_period(
    jaipur_holdout
)

# %%
holdout_results = [

    delhi_holdout,
    mumbai_holdout,
    bengaluru_holdout,
    hyderabad_holdout,
    ahmedabad_holdout,
    chennai_holdout,
    kolkata_holdout,
    surat_holdout,
    pune_holdout,
    jaipur_holdout

]
holdout_comparison = (
    hourly.create_holdout_comparison_table(
        holdout_results
    )
)

holdout_comparison
# Out:
#          City      RMSE       MAE        R²  Correlation
# 1       Delhi  0.866721  0.735285  0.948017     0.974884
# 2      Mumbai  0.414534  0.321985  0.922673     0.962236
# 3   Bengaluru  0.760248  0.592318  0.912153     0.957709
# 4   Hyderabad  0.967969  0.765662  0.907049     0.953961
# 5   Ahmedabad  0.755139  0.619693  0.951715     0.976206
# 6     Chennai  0.594924  0.426026  0.912751     0.959527
# 7     Kolkata  0.938411  0.708399  0.860692     0.931307
# 8       Surat  0.398884  0.328206  0.896645     0.951900
# 9        Pune  0.804921  0.655061  0.930048     0.966391
# 10     Jaipur  1.067657  0.846288  0.933974     0.967755

# %%
test_comparison = hourly.create_test_comparison_table(
    test_results
)

test_comparison
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 test_comparison = hourly.create_test_comparison_table(
# ----> 2     test_results
#       3 )
#       4
#       5 test_comparison
#
# NameError: name 'test_results' is not defined

# %%
full_comparison = hourly.create_full_comparison_table(
    test_results,
    holdout_results
)

full_comparison
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 full_comparison = hourly.create_full_comparison_table(
# ----> 2     test_results,
#       3     holdout_results
#       4 )
#       5
#
# NameError: name 'test_results' is not defined

# %%
full_comparison.to_csv(
    "../outputs/hourly_2000_2010_vs_june2026.csv",
    index=True
)

print("CSV saved successfully!")
# Out:
# CSV saved successfully!
