# %%
import numpy as np
import tensorflow as tf
import random

np.random.seed(42)

tf.random.set_seed(42)

random.seed(42)

# %%
import sys

sys.path.append("..")

import importlib

import scripts.utils as utils

importlib.reload(utils)
# Out:
# <module 'scripts.utils' from '/home/rupin/ERA5_LSTM_Project/notebooks/../scripts/utils.py'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# 1. DELHI

# %%
delhi_results = utils.train_city_model(
    city_name="delhi",
    sequence_length=30,
    epochs=20 
)
# Out:
# Training Period:
# 2000-01-01 to 2008-10-24
#
# Testing Period:
# 2008-10-25 to 2010-12-31
# E0000 00:00:1781003699.140902   23299 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
utils.plot_predictions(
    delhi_results
)

# %%
print("Delhi Metrics")

print("RMSE:",
      delhi_results["rmse"])

print("MAE:",
      delhi_results["mae"])

print("Correlation:",
      delhi_results["correlation"])

print("R²:",
      delhi_results["r2"])
# Out:
# Delhi Metrics
# RMSE: 1.0542371018125896
# MAE: 0.7968241314058626
# Correlation: 0.9879115224283245
# R²: 0.9756411776210241

# %% [markdown]
# 2.MUMBAI

# %%
mumbai_results = utils.train_city_model(
    city_name="mumbai",
    sequence_length=30,
    epochs=20
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
utils.plot_predictions(
    mumbai_results
)

# %%
print("Mumbai Metrics")

print("RMSE:",
      mumbai_results["rmse"])

print("MAE:",
      mumbai_results["mae"])

print("Correlation:",
      mumbai_results["correlation"])

print("R²:",
      mumbai_results["r2"])
# Out:
# Mumbai Metrics
# RMSE: 1.208777695554964
# MAE: 0.9012871866001544
# Correlation: 0.9877348816379806
# R²: 0.9754393205833968

# %% [markdown]
# 3.Bengaluru

# %%
bengaluru_results = utils.train_city_model(
    city_name="Bengaluru",
    sequence_length=30,
    epochs=20
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
utils.plot_predictions(
    bengaluru_results
)

# %%
print("Bengaluru Metrics")

print("RMSE:",
      bengaluru_results["rmse"])

print("MAE:",
      bengaluru_results["mae"])

print("Correlation:",
      bengaluru_results["correlation"])

print("R²:",
      bengaluru_results["r2"])
# Out:
# Bengaluru Metrics
# RMSE: 1.0203126194619427
# MAE: 0.7655278689066575
# Correlation: 0.9882164178301708
# R²: 0.9763787791846522

# %% [markdown]
# 4.HYDERABAD

# %%
hyderabad_results = utils.train_city_model(
    city_name="Hyderabad",
    sequence_length=30,
    epochs=20
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
utils.plot_predictions(
    hyderabad_results
)

# %%
print("Hyderabad Metrics")

print("RMSE:",
      hyderabad_results["rmse"])

print("MAE:",
      hyderabad_results["mae"])

print("Correlation:",
      hyderabad_results["correlation"])

print("R²:",
      hyderabad_results["r2"])
# Out:
# Hyderabad Metrics
# RMSE: 1.0212876597295715
# MAE: 0.77591178239904
# Correlation: 0.9874304185854538
# R²: 0.974818235303776

# %% [markdown]
# 5.AHEMDABAD

# %%
ahmedabad_results = utils.train_city_model(
    city_name="ahmedabad",
    sequence_length=30,
    epochs=20
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
utils.plot_predictions(
    ahmedabad_results
)

# %%
print("ahmedabad Metrics")

print("RMSE:",
      ahmedabad_results["rmse"])

print("MAE:",
     ahmedabad_results["mae"])

print("Correlation:",
      ahmedabad_results["correlation"])

print("R²:",
      ahmedabad_results["r2"])
# Out:
# ahmedabad Metrics
# RMSE: 1.2353686486537665
# MAE: 0.910348488115961
# Correlation: 0.9880282113059917
# R²: 0.9751055343575572

# %% [markdown]
# 6.CHENNAI

# %%
chennai_results = utils.train_city_model(
    city_name="chennai",
    sequence_length=30,
    epochs=20
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
utils.plot_predictions(
    chennai_results
)

# %%
print("Chennai Metrics")

print("RMSE:",
      chennai_results["rmse"])

print("MAE:",
     chennai_results["mae"])

print("Correlation:",
      chennai_results["correlation"])

print("R²:",
      chennai_results["r2"])
# Out:
# Chennai Metrics
# RMSE: 1.0502741007603014
# MAE: 0.79247740150012
# Correlation: 0.9867750123246746
# R²: 0.9733685198308101

# %% [markdown]
# 7. KOLKATA

# %%
kolkata_results = utils.train_city_model(
    city_name="kolkata",
    sequence_length=30,
    epochs=20
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
utils.plot_predictions(
    kolkata_results
)

# %%
print("kolkata Metrics")

print("RMSE:",
      kolkata_results["rmse"])

print("MAE:",
     kolkata_results["mae"])

print("Correlation:",
      kolkata_results["correlation"])

print("R2:",
      kolkata_results["r2"])
# Out:
# kolkata Metrics
# RMSE: 1.0457750025709847
# MAE: 0.7913250073922918
# Correlation: 0.9868926303894636
# R2: 0.9735961956546246

# %% [markdown]
# 8. SURAT

# %%
surat_results = utils.train_city_model(
    city_name="surat",
    sequence_length=30,
    epochs=20
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
utils.plot_predictions(
    surat_results
)

# %%
print("surat Metrics")

print("RMSE:",
      surat_results["rmse"])

print("MAE:",
     surat_results["mae"])

print("Correlation:",
      surat_results["correlation"])

print("R2:",
      surat_results["r2"])
# Out:
# surat Metrics
# RMSE: 1.2052796634250311
# MAE: 0.9013127672506188
# Correlation: 0.9879542245262716
# R2: 0.9758453206244664

# %% [markdown]
# 9. PUNE

# %%
pune_results = utils.train_city_model(
    city_name="pune",
    sequence_length=30,
    epochs=20
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
utils.plot_predictions(
    pune_results
)

# %%
print("pune Metrics")

print("RMSE:",
      pune_results["rmse"])

print("MAE:",
     pune_results["mae"])

print("Correlation:",
      pune_results["correlation"])

print("R2:",
      pune_results["r2"])
# Out:
# pune Metrics
# RMSE: 1.2860573427313975
# MAE: 0.9625262388415887
# Correlation: 0.9864499821936739
# R2: 0.9706684487783842

# %% [markdown]
# 10. JAIPUR

# %%
jaipur_results = utils.train_city_model(
    city_name="jaipur",
    sequence_length=30,
    epochs=20
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
utils.plot_predictions(
    jaipur_results
)

# %%
print("jaipur Metrics")

print("RMSE:",
      jaipur_results["rmse"])

print("MAE:",
     jaipur_results["mae"])

print("Correlation:",
      jaipur_results["correlation"])

print("R2:",
      jaipur_results["r2"])
# Out:
# jaipur Metrics
# RMSE: 1.1372622342941032
# MAE: 0.8372249368844467
# Correlation: 0.9873409715241379
# R2: 0.9745861568041311

# %%
results = [
    delhi_results,
    mumbai_results,
    bengaluru_results,
    hyderabad_results,
    ahmedabad_results,
    chennai_results,
    kolkata_results,
    surat_results,
    pune_results,
    jaipur_results
]

comparison = utils.create_comparison_table(
    results
)

comparison.index = comparison.index + 1

comparison

# %%
#Evaluation metrices
comparison = pd.DataFrame({

    "City": [
        "Delhi",
        "Mumbai",
        "Bengaluru",
        "Hyderabad",
        "Ahmedabad",
        "Chennai",
        "Kolkata",
        "Surat",
        "Pune",
        "Jaipur"
    ],

    "RMSE": [
        delhi_results["rmse"],
        mumbai_results["rmse"],
        bengaluru_results["rmse"],
        hyderabad_results["rmse"],
        ahmedabad_results["rmse"],
        chennai_results["rmse"],
        kolkata_results["rmse"],
        surat_results["rmse"],
        pune_results["rmse"],
        jaipur_results["rmse"]

    ],

    "MAE": [
        delhi_results["mae"],
        mumbai_results["mae"],
        bengaluru_results["mae"],
        hyderabad_results["mae"],
        ahmedabad_results["mae"],
        chennai_results["mae"],
        kolkata_results["mae"],
        surat_results["mae"],
        pune_results["mae"],
        jaipur_results["mae"]
    ],

    "Correlation": [
        delhi_results["correlation"],
        mumbai_results["correlation"],
        bengaluru_results["correlation"],
        hyderabad_results["correlation"],
        ahmedabad_results["correlation"],
        chennai_results["correlation"],
        kolkata_results["correlation"],
        surat_results["correlation"],
        pune_results["correlation"],
        jaipur_results["correlation"]
    ],

    "R²": [
        delhi_results["r2"],
        mumbai_results["r2"],
        bengaluru_results["r2"],
        hyderabad_results["r2"],
        ahmedabad_results["r2"],
        chennai_results["r2"],
        kolkata_results["r2"],
        surat_results["r2"],
        pune_results["r2"],
        jaipur_results["r2"]
    ]
})
comparison.index = comparison.index + 1
comparison
# Out:
#          City      RMSE       MAE  Correlation        R²
# 1       Delhi  1.054237  0.796824     0.987912  0.975641
# 2      Mumbai  1.208778  0.901287     0.987735  0.975439
# 3   Bengaluru  1.020313  0.765528     0.988216  0.976379
# 4   Hyderabad  1.021288  0.775912     0.987430  0.974818
# 5   Ahmedabad  1.235369  0.910348     0.988028  0.975106
# 6     Chennai  1.050274  0.792477     0.986775  0.973369
# 7     Kolkata  1.045775  0.791325     0.986893  0.973596
# 8       Surat  1.205280  0.901313     0.987954  0.975845
# 9        Pune  1.286057  0.962526     0.986450  0.970668
# 10     Jaipur  1.137262  0.837225     0.987341  0.974586

# %%
comparison.to_csv(
    "../outputs/results_table.csv",
    index=False
)

print("Saved successfully")
# Out:
# Saved successfully
